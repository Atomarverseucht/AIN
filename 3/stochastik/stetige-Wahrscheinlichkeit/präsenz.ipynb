# %%
import numpy as np
import scipy.stats as stat

# %%
x1 = stat.geom(0.25)
x2 = stat.binom(10, 0.75)
x3 = stat.poisson(5)

print(x2.sf(4))
print(x1.pmf(4))
# Out:
# 0.9802722930908203
# 0.10546875
