# %%
import scipy.stats as stats

# %%
N = stats.norm(200, 10)
print(f" 90% der Werte liegen zwischen: {N.ppf(0.05)} bis {N.ppf(0.95)}")
# Out:
#  90% der Werte liegen zwischen: 183.55146373048527 bis 216.44853626951473
